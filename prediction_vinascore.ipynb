# %% [markdown]
# <a href="https://colab.research.google.com/github/susmita2000/Drug_repurposing/blob/main/prediction_vinascore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os
import requests
import subprocess
import shutil
from logging import getLogger, StreamHandler, INFO


logger = getLogger(__name__)
logger.addHandler(StreamHandler())
logger.setLevel(INFO)


def install(
        chunk_size=4096,
        file_name="Miniconda3-latest-Linux-x86_64.sh",
        url_base="https://repo.continuum.io/miniconda/",
        conda_path=os.path.expanduser(os.path.join("~", "miniconda")),
        rdkit_version=None,
        add_python_path=True,
        force=False):
    """install rdkit from miniconda
    ```
    import rdkit_installer
    rdkit_installer.install()
    ```
    """

    python_path = os.path.join(
        conda_path,
        "lib",
        "python{0}.{1}".format(*sys.version_info),
        "site-packages",
    )

    if add_python_path and python_path not in sys.path:
        logger.info("add {} to PYTHONPATH".format(python_path))
        sys.path.append(python_path)

    if os.path.isdir(os.path.join(python_path, "rdkit")):
        logger.info("rdkit is already installed")
        if not force:
            return

        logger.info("force re-install")

    url = url_base + file_name
    python_version = "{0}.{1}.{2}".format(*sys.version_info)

    logger.info("python version: {}".format(python_version))

    if os.path.isdir(conda_path):
        logger.warning("remove current miniconda")
        shutil.rmtree(conda_path)
    elif os.path.isfile(conda_path):
        logger.warning("remove {}".format(conda_path))
        os.remove(conda_path)

    logger.info('fetching installer from {}'.format(url))
    res = requests.get(url, stream=True)
    res.raise_for_status()
    with open(file_name, 'wb') as f:
        for chunk in res.iter_content(chunk_size):
            f.write(chunk)
    logger.info('done')

    logger.info('installing miniconda to {}'.format(conda_path))
    subprocess.check_call(["bash", file_name, "-b", "-p", conda_path])
    logger.info('done')

    logger.info("installing rdkit")
    subprocess.check_call([
        os.path.join(conda_path, "bin", "conda"),
        "install",
        "--yes",
        "-c", "rdkit",
        "python=={}".format(python_version),
        "rdkit" if rdkit_version is None else "rdkit=={}".format(rdkit_version)])
    logger.info("done")

    import rdkit
    logger.info("rdkit-{} installation finished!".format(rdkit.__version__))


if __name__ == "__main__":
    install()
# Out:
# add /root/miniconda/lib/python3.7/site-packages to PYTHONPATH
# python version: 3.7.10
# fetching installer from https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# done
# installing miniconda to /root/miniconda
# done
# installing rdkit
# done
# rdkit-2020.09.1 installation finished!

# %%
from rdkit import Chem

# %%
# !pip install git+https://github.com/samoturk/mol2vec
# Out:
# Collecting git+https://github.com/samoturk/mol2vec
#   Cloning https://github.com/samoturk/mol2vec to /tmp/pip-req-build-7va5dtk8
#   Running command git clone -q https://github.com/samoturk/mol2vec /tmp/pip-req-build-7va5dtk8
# Collecting numpy
#   Downloading numpy-1.20.2-cp37-cp37m-manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 140 kB/s
# Collecting gensim
#   Downloading gensim-4.0.1-cp37-cp37m-manylinux1_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 58.5 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/site-packages (from mol2vec==0.1) (4.51.0)
# Collecting joblib
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 45.4 MB/s
# Collecting pandas
#   Downloading pandas-1.2.3-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 45.2 MB/s
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 40.7 MB/s
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/site-packages (from mol2vec==0.1) (7.22.0)
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#      |████████████████████████████████| 285 kB 50.3 MB/s
# Collecting scipy>=0.18.1
#   Downloading scipy-1.6.2-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 132 kB/s
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.0.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.4 MB/s
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/site-packages (from IPython->mol2vec==0.1) (3.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/site-packages (from IPython->mol2vec==0.1) (49.6.0.post20210108)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/site-packages (from IPython->mol2vec==0.1) (0.18.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/site-packages (from IPython->mol2vec==0.1) (2.8.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/site-packages (from IPython->mol2vec==0.1) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/site-packages (from IPython->mol2vec==0.1) (5.0.3)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/site-packages (from IPython->mol2vec==0.1) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/site-packages (from IPython->mol2vec==0.1) (5.0.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/site-packages (from IPython->mol2vec==0.1) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/site-packages (from jedi>=0.16->IPython->mol2vec==0.1) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/site-packages (from pexpect>4.3->IPython->mol2vec==0.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->mol2vec==0.1) (0.2.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/site-packages (from traitlets>=4.2->IPython->mol2vec==0.1) (0.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->mol2vec==0.1) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 39.5 MB/s
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 39.4 MB/s
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 50.5 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->mol2vec==0.1) (1.15.0)
# Collecting pytz>=2017.3
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 48.7 MB/s
# Building wheels for collected packages: mol2vec
#   Building wheel for mol2vec (setup.py) ... done
#   Created wheel for mol2vec: filename=mol2vec-0.1-py3-none-any.whl size=14025 sha256=e41a7eae6115ea38d1ba35ad1a7eef569347826ca2ff487d37cd2b074a81dc1a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_8itbrg7/wheels/80/d5/e1/90dc211e4a17780f99eaec43328470a70284cd731ef2a77034
# Successfully built mol2vec
# Installing collected packages: pytz, python-dateutil, pillow, numpy, kiwisolver, cycler, smart-open, scipy, pandas, matplotlib, seaborn, joblib, gensim, mol2vec
# Successfully installed cycler-0.10.0 gensim-4.0.1 joblib-1.0.1 kiwisolver-1.3.1 matplotlib-3.4.1 mol2vec-0.1 numpy-1.20.2 pandas-1.2.3 pillow-8.2.0 python-dateutil-2.8.1 pytz-2021.1 scipy-1.6.2 seaborn-0.11.1 smart-open-5.0.0

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/My Drive/supercompf.csv')

target=df['vina_score']
df2=df[['smiles']]
df2['mol'] = df2['smiles'].apply(lambda x: Chem.MolFromSmiles(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from gensim.models import word2vec
from mol2vec import features
from mol2vec import helpers
from mol2vec.features import mol2alt_sentence, mol2sentence, MolSentence, DfVec, sentences2vec
df2['sentence'] = df2.apply(lambda x: MolSentence(mol2alt_sentence(x['mol'], 1)), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
model = word2vec.Word2Vec.load('/content/drive/My Drive/model_300dim.pkl')
import numpy as np
df2['mol2vec'] = [DfVec(x) for x in sentences2vec(df2['sentence'], model, unseen='UNK')]
X = np.array([x.vec for x in df2['mol2vec']])
y = target.values
X.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# (9002, 300)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
def evaluation(model, X_test, y_test):
    prediction = model.predict(X_test)
    mae = mean_absolute_error(y_test, prediction)
    mse = mean_squared_error(y_test, prediction,squared=False)
    r2_score_val = r2_score(y_test, prediction)
    
    plt.figure(figsize=(15, 10))
    plt.plot(prediction[:300], "red", label="prediction", linewidth=1.0)
    plt.plot(y_test[:300], 'green', label="actual", linewidth=1.0)
    plt.legend()
    plt.ylabel('Vina_score')
    plt.title("MAE {}, MSE {}".format(round(mae, 4), round(mse, 4)))
    plt.show()
    
    print('MAE score:', round(mae, 4))
    print('rMSE score:', round(mse,4))
    print('R2 score:', round(r2_score_val,4))

# %%
 from sklearn.ensemble import RandomForestRegressor
 from sklearn.model_selection import train_test_split
 import matplotlib.pyplot as plt
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

regr = RandomForestRegressor(max_depth=7, random_state=1)
#cv = cross_validate(model, X, y, cv=5)
regr.fit(X, y)
evaluation(regr, X_test, y_test)
# Out:
# MAE score: 0.33
# rMSE score: 0.4532
# R2 score: 0.8339

# %% [markdown]
# Github push

# %%
# !git init
